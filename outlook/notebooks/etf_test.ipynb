# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import importlib
import numpy as np
import sys
import os

import tensorflow as tf
from sklearn.model_selection import train_test_split

sys.path.append(os.path.abspath('../../'))

import utils.ml_util
importlib.reload(utils.ml_util)
from utils.ml_util import *

import utils.trading_util
importlib.reload(utils.trading_util)
from utils.trading_util import *

# %%
TKR = 'XLE'
MAX_HOLDING = 100
FEATURE_KERNEL_SIZES = [5, 10, 20, 50, 70, 100]
TEST_TRAIN_SPLIT = pd.Timestamp('2017-01-01')
TIME_EFFECT = 3

historic_prices = yf.download(TKR)['Adj Close']
train_prices, test_prices = historic_prices[TKR][:TEST_TRAIN_SPLIT].to_list(), historic_prices[TKR][TEST_TRAIN_SPLIT:].to_list()
plt.figure(figsize=(14, 7))
plt.plot(historic_prices[TKR][:TEST_TRAIN_SPLIT], label='Train Prices')
plt.plot(historic_prices[TKR][TEST_TRAIN_SPLIT:], label='Test Prices')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')
plt.title(f'{TKR} Stock Prices')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
outlook = []
for pos1 in range(len(train_prices) - MAX_HOLDING):
    ans = 0
    for pos2 in range(1, MAX_HOLDING):
        ans += (train_prices[pos1 + pos2] - train_prices[pos1]) * time_effect[TIME_EFFECT](MAX_HOLDING, pos2)
    outlook.append(ans / integrated_time_effect[TIME_EFFECT])
    
n_outlook = normalize_average(outlook, MAX_HOLDING * 3)

# %%
features = get_sma_sd_v(train_prices, FEATURE_KERNEL_SIZES, max(FEATURE_KERNEL_SIZES))
for pos in range(len(features)):
    features[pos] = features[pos][:-MAX_HOLDING - 1]
n_outlook = n_outlook[max(FEATURE_KERNEL_SIZES):]

x = np.array(transpose(features))
y = np.array(n_outlook)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

def create_model():
    return tf.keras.models.Sequential([
        tf.keras.layers.Input(shape=(len(FEATURE_KERNEL_SIZES) * 3,)),
        tf.keras.layers.Flatten(name='layers_flatten'),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(1, activation='tanh'),
    ])

model = create_model()
model.compile(optimizer='adam',
            loss='mean_absolute_error',)

# %%
model.fit(x=x_train, 
        y=y_train, 
        epochs=70, 
        validation_data=(x_test, y_test), 
    )
# Out:
# Epoch 1/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.5225 - val_loss: 0.3237
# Epoch 2/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3396 - val_loss: 0.3459
# Epoch 3/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3311 - val_loss: 0.3271
# Epoch 4/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3364 - val_loss: 0.3170
# Epoch 5/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3230 - val_loss: 0.3193
# Epoch 6/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3248 - val_loss: 0.3232
# Epoch 7/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3220 - val_loss: 0.3168
# Epoch 8/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3046 - val_loss: 0.3067
# Epoch 9/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3048 - val_loss: 0.2936
# Epoch 10/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2935 - val_loss: 0.2910
# Epoch 11/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2804 - val_loss: 0.2710
# Epoch 12/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2765 - val_loss: 0.2607
# Epoch 13/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2716 - val_loss: 0.2676
# Epoch 14/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2581 - val_loss: 0.2465
# Epoch 15/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2424 - val_loss: 0.2662
# Epoch 16/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2481 - val_loss: 0.2496
# Epoch 17/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2393 - val_loss: 0.2328
# Epoch 18/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2223 - val_loss: 0.2337
# Epoch 19/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2194 - val_loss: 0.2285
# Epoch 20/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2207 - val_loss: 0.2223
# Epoch 21/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2155 - val_loss: 0.2214
# Epoch 22/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1972 - val_loss: 0.1949
# Epoch 23/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1895 - val_loss: 0.2097
# Epoch 24/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2038 - val_loss: 0.2033
# Epoch 25/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1742 - val_loss: 0.1871
# Epoch 26/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1807 - val_loss: 0.2048
# Epoch 27/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1780 - val_loss: 0.2080
# Epoch 28/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1749 - val_loss: 0.1738
# Epoch 29/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1615 - val_loss: 0.1787
# Epoch 30/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1646 - val_loss: 0.1817
# Epoch 31/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1726 - val_loss: 0.1893
# Epoch 32/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1660 - val_loss: 0.1559
# Epoch 33/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1479 - val_loss: 0.1463
# Epoch 34/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1418 - val_loss: 0.1825
# Epoch 35/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1458 - val_loss: 0.1482
# Epoch 36/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1447 - val_loss: 0.1594
# Epoch 37/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1441 - val_loss: 0.1491
# Epoch 38/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1389 - val_loss: 0.1645
# Epoch 39/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1377 - val_loss: 0.1517
# Epoch 40/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1334 - val_loss: 0.1537
# Epoch 41/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1267 - val_loss: 0.1271
# Epoch 42/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1279 - val_loss: 0.1265
# Epoch 43/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1256 - val_loss: 0.1327
# Epoch 44/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1219 - val_loss: 0.1361
# Epoch 45/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1217 - val_loss: 0.1326
# Epoch 46/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1161 - val_loss: 0.1241
# Epoch 47/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1135 - val_loss: 0.1587
# Epoch 48/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1304 - val_loss: 0.1376
# Epoch 49/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1122 - val_loss: 0.1191
# Epoch 50/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1099 - val_loss: 0.1231
# Epoch 51/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1039 - val_loss: 0.1529
# Epoch 52/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1294 - val_loss: 0.1200
# Epoch 53/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1046 - val_loss: 0.1332
# Epoch 54/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1135 - val_loss: 0.1204
# Epoch 55/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1117 - val_loss: 0.1190
# Epoch 56/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1065 - val_loss: 0.1312
# Epoch 57/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1129 - val_loss: 0.1121
# Epoch 58/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0983 - val_loss: 0.1177
# Epoch 59/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0971 - val_loss: 0.1143
# Epoch 60/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0979 - val_loss: 0.1226
# Epoch 61/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0962 - val_loss: 0.1301
# Epoch 62/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1071 - val_loss: 0.1234
# Epoch 63/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1096 - val_loss: 0.1147
# Epoch 64/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1003 - val_loss: 0.1183
# Epoch 65/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0962 - val_loss: 0.1170
# Epoch 66/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0992 - val_loss: 0.1175
# Epoch 67/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0970 - val_loss: 0.1088
# Epoch 68/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0948 - val_loss: 0.1068
# Epoch 69/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0899 - val_loss: 0.1189
# Epoch 70/70
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0965 - val_loss: 0.1087

# %%
features = get_sma_sd_v(test_prices, FEATURE_KERNEL_SIZES, max(FEATURE_KERNEL_SIZES))
test_prices = test_prices[max(FEATURE_KERNEL_SIZES) - 1:]

x = np.array(transpose(features))

p_outlook = model.predict(x)
p_outlook = [x[0] for x in p_outlook]
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
account = Account()
stock = Stock(TKR, test_prices[0])
MAX_TRANSACTION = 1

buy_positions = []
sell_positions = []
executed_sell_orders = []
executed_cover_orders = []

net_worth = []
min_balance = 0

for pos in range(len(test_prices)):
    stock.update_price(test_prices[pos])
    
    if p_outlook[pos] > 0.2:
        account.buy(stock, abs(MAX_TRANSACTION * p_outlook[pos]))
        buy_positions.append((pos, test_prices[pos]))
    elif p_outlook[pos] < -0.7:
        account.sell(stock, abs(MAX_TRANSACTION * p_outlook[pos]))
        sell_positions.append((pos, test_prices[pos]))
    
    net_worth.append(float(account.net_worth()))
    if account.balance < min_balance:
        min_balance = account.balance

# %%
fig, ax1 = plt.subplots(figsize=(12, 6))

ax1.plot(range(len(test_prices)), test_prices, label="Stock Price", color="blue")
ax1.set_xlabel("Time Steps")
ax1.set_ylabel("Price", color="blue")
ax1.tick_params(axis="y", labelcolor="blue")

buy_x, buy_y = zip(*buy_positions) if buy_positions else ([], [])
ax1.scatter(buy_x, buy_y, label="Buy Positions", color="green", marker="^", alpha=0.8)

sell_x, sell_y = zip(*sell_positions) if sell_positions else ([], [])
ax1.scatter(sell_x, sell_y, label="Sell Positions", color="red", marker="v", alpha=0.8)

ax2 = ax1.twinx()
ax2.plot(range(len(p_outlook)), p_outlook, label="Predicted Outlook", color="green", linestyle="--")
ax2.set_ylabel("Outlook", color="black")
ax2.tick_params(axis="y", labelcolor="black")

lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc="lower right")

plt.title("Stock Price with Overlayed Outlook and Transactions")
plt.grid()
plt.tight_layout()

plt.show()

plt.figure(figsize=(12, 6))
plt.plot(range(len(net_worth)), net_worth, label="Net Worth", color="green", linestyle="--")

plt.title("Net Worth Over Time")
plt.xlabel("Time Steps")
plt.ylabel("Net Worth")
plt.legend()
plt.grid()

plt.show()

print(account)
print(f"Stock Profit: {(test_prices[-1] - test_prices[0]) / test_prices[0] * 100:.2f}%")
# Out:
# Balance: $5610.94
# Net Worth: $6120.55
# Total Profit: 85.27%
# Holdings:
# XLE: 6.056764125823975 shares
# Stock Profit: 76.70%
